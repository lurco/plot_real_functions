# %% [markdown]
# # Wykresy funkcji liczbowo-liczbowych, przekształcenia

# %%
import jupyter_black
jupyter_black.load()
from plotting import plot_function

# %%
def f(x):
    return x**3 - 3


def f2(x):
    return f(abs(x))

# %%
plot_function(f, f2, x_start=-2, x_end=2, label="f(x) oraz f(|x|)")
